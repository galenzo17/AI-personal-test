# %% [markdown]
# <a href="https://colab.research.google.com/github/galenzo17/AI-personal-test/blob/main/genesis_test.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Instalar Genesis desde PyPI
# !pip install genesis-world

# Instalar PyTorch; ajusta la versión según tu entorno y necesidades
# !pip install torch torchvision torchaudio

# (Opcional) Instalar OMPL para planificación de movimientos
# Descarga la rueda precompilada de OMPL desde el repositorio de Genesis
# !wget https://github.com/Genesis-Embodied-AI/Genesis/releases/download/v0.2.0/ompl-1.5.2-cp39-cp39-manylinux2014_x86_64.whl
# Instala la rueda descargada
# !pip install ompl-1.5.2-cp39-cp39-manylinux2014_x86_64.whl

# (Opcional) Instalar Splashsurf para la reconstrucción de superficies
# Instala Rust si no está instalado
# !curl --proto '=https' --tlsv1.2 -sSf https://sh.rustup.rs | sh -s -- -y
# Asegúrate de que Cargo (el gestor de paquetes de Rust) esté en el PATH
import os
os.environ['PATH'] += os.pathsep + os.path.expanduser('~/.cargo/bin')
# Instala Splashsurf
# !cargo install splashsurf

# (Opcional) Configurar ParticleMesher para la reconstrucción de superficies
# Clona el repositorio de ParticleMesher
# !git clone https://github.com/Genesis-Embodied-AI/ParticleMesher.git
# Navega al directorio de ParticleMesher
# %cd ParticleMesher
# Compila ParticleMesher
# !mkdir build && cd build && cmake .. && make
# Agrega ParticleMesher al LD_LIBRARY_PATH
import os
os.environ['LD_LIBRARY_PATH'] = os.environ.get('LD_LIBRARY_PATH', '') + os.pathsep + os.path.abspath('build')
# Vuelve al directorio principal
# %cd ..

# (Opcional) Configurar LuisaRender para renderizado por trazado de rayos
# Clona el submódulo LuisaRender
# !git submodule update --init --recursive
# Instala las dependencias necesarias
# !sudo apt-get update
# !sudo apt-get install -y build-essential cmake libvulkan-dev zlib1g-dev xorg-dev libglu1-mesa-dev libsnappy-dev
# Instala GCC y G++ versión 11
# !sudo add-apt-repository ppa:ubuntu-toolchain-r/test -y
# !sudo apt-get update
# !sudo apt-get install -y gcc-11 g++-11
# !sudo update-alternatives --install /usr/bin/gcc gcc /usr/bin/gcc-11 110
# !sudo update-alternatives --install /usr/bin/g++ g++ /usr/bin/g++-11 110
# Verifica las versiones instaladas
# !gcc --version
# !g++ --version
# Instala Rust
# !curl --proto '=https' --tlsv1.2 -sSf https://sh.rustup.rs | sh -s -- -y
# Asegúrate de que Cargo esté en el PATH
import os
os.environ['PATH'] += os.pathsep + os.path.expanduser('~/.cargo/bin')
# Compila LuisaRender
# %cd ext/LuisaRender
# !mkdir build && cd build && cmake .. && make
# Vuelve al directorio principal
# %cd ..

# Verifica la instalación de Genesis
import genesis
print("Genesis instalado correctamente:", genesis.__version__)
# Out:
# ...
# --2024-12-20 00:22:26--  https://github.com/Genesis-Embodied-AI/Genesis/releases/download/v0.2.0/ompl-1.5.2-cp39-cp39-manylinux2014_x86_64.whl
# Resolving github.com (github.com)... 140.82.112.4
# Connecting to github.com (github.com)|140.82.112.4|:443... connected.
# HTTP request sent, awaiting response... 404 Not Found
# 2024-12-20 00:22:26 ERROR 404: Not Found.
#
# WARNING: Requirement 'ompl-1.5.2-cp39-cp39-manylinux2014_x86_64.whl' looks like a filename, but the file does not exist
# ERROR: ompl-1.5.2-cp39-cp39-manylinux2014_x86_64.whl is not a supported wheel on this platform.
# info: downloading installer
# info: profile set to 'default'
# info: default host triple is x86_64-unknown-linux-gnu
# ...
# info: syncing channel updates for 'stable-x86_64-unknown-linux-gnu'
# info: default toolchain set to 'stable-x86_64-unknown-linux-gnu'
#
#   stable-x86_64-unknown-linux-gnu unchanged - rustc 1.83.0 (90b35a623 2024-11-26)
#
#
# Rust is installed now. Great!
#
# ...
