# %% [markdown]
# <a href="https://colab.research.google.com/github/galenzo17/AI-personal-test/blob/main/mochi_test.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Clonar el repositorio de Mochi 1
# !git clone https://github.com/genmoai/models
# %cd models

# Instalar los paquetes requeridos
# !pip install numpy torch torchvision tqdm transformers safetensors diffusers einops torch-ema huggingface_hub timm matplotlib pillow wandb protobuf

# Instalar el paquete de Mochi 1
# !pip install -e .

# Instalar FFMPEG para convertir las salidas en videos
# !apt-get install ffmpeg -y

# Descargar los pesos del modelo
# !python ./scripts/download_weights.py ./mochi_weights

# Ejecutar la interfaz de usuario de Gradio
# !python ./demos/gradio_ui.py --model_dir "./mochi_weights"
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 57.1/57.1 MB 30.5 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 320.1/320.1 kB 18.4 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 94.9/94.9 kB 6.9 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 11.1/11.1 MB 109.5 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 73.2/73.2 kB 6.2 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 63.8/63.8 kB 5.3 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 130.2/130.2 kB 12.8 MB/s eta 0:00:00
# ...
#   Attempting uninstall: markupsafe
#     Found existing installation: MarkupSafe 3.0.2
#     Uninstalling MarkupSafe-3.0.2:
#       Successfully uninstalled MarkupSafe-3.0.2
# ...
# Cloning into 'models'...
# remote: Enumerating objects: 331, done.
# remote: Counting objects: 100% (175/175), done.
# remote: Compressing objects: 100% (79/79), done.
# remote: Total 331 (delta 105), reused 114 (delta 90), pack-reused 156 (from 1)
# ...
